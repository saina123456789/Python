# %% [markdown]
# # <b>Subject: DPFE
#    Branch : CSE - Data Science
#    USN    : 21BTRCD028
#    Name   : A B Yogendra Naidu
# </b>

# %% [markdown]
# <b>1)Create a Dataset Of your Own House, Such that you are analysing dataset & its different variables using pandas methods.Also use dropna(), fillna(mean,median,mode), Encoding techniques-replace(),category().get_dummies,Sklearn-ordinalencoder().</b>

# %%
#Create a Dataset Of your Own school, Such that you are analysing dataset & its different variables using pandas methods.Also use dropna(), fillna(mean,median,mode), Encoding techniques-replace(),category().get_dummies,Sklearn-ordinalencoder().
import pandas as pd
import numpy as np

# %%
import numpy as np

# %%
d=pd.read_excel("School.xlsx")
df=pd.DataFrame(d)
df
# Out:
#     Area no of boys no of girls  Age Electricity_bill
# 0   1000          3           2   15              100
# 1   1900          3           2   10              110
# 2   2300       none           3   18             none
# 3   1700          2           2   13              120
# 4   none          2           1    6               90
# 5   2900          3           2    4              130
# 6   5600          2           1   16             none
# 7  nnone          4           3   15              140
# 8   1300          3        none   16               95
# 9   2400          3           2   13              115

# %%
#Dropping null values using dropna()
std=df.dropna()
std
# Out:
#     Area no of boys no of girls  Age Electricity_bill
# 0   1000          3           2   15              100
# 1   1900          3           2   10              110
# 2   2300       none           3   18             none
# 3   1700          2           2   13              120
# 4   none          2           1    6               90
# 5   2900          3           2    4              130
# 6   5600          2           1   16             none
# 7  nnone          4           3   15              140
# 8   1300          3        none   16               95
# 9   2400          3           2   13              115

# %%
#filling all nul values
x=df["Age"].mean()
x
# Out:
# 12.6

# %%
d1=df.fillna(x)
d1
# Out:
#     Area no of boys no of girls  Age Electricity_bill
# 0   1000          3           2   15              100
# 1   1900          3           2   10              110
# 2   2300       none           3   18             none
# 3   1700          2           2   13              120
# 4   none          2           1    6               90
# 5   2900          3           2    4              130
# 6   5600          2           1   16             none
# 7  nnone          4           3   15              140
# 8   1300          3        none   16               95
# 9   2400          3           2   13              115

# %%
y=df["no of girls"].mode()
y
# Out:
# 0    2
# Name: no of girls, dtype: object

# %%
d2=df.fillna(y)
d2
# Out:
#     Area no of boys no of girls  Age Electricity_bill
# 0   1000          3           2   15              100
# 1   1900          3           2   10              110
# 2   2300       none           3   18             none
# 3   1700          2           2   13              120
# 4   none          2           1    6               90
# 5   2900          3           2    4              130
# 6   5600          2           1   16             none
# 7  nnone          4           3   15              140
# 8   1300          3        none   16               95
# 9   2400          3           2   13              115

# %%
z=df["Age"].median()
z
# Out:
# 14.0

# %%
d3=df.fillna(z)
d3
# Out:
#     Area no of boys no of girls  Age Electricity_bill
# 0   1000          3           2   15              100
# 1   1900          3           2   10              110
# 2   2300       none           3   18             none
# 3   1700          2           2   13              120
# 4   none          2           1    6               90
# 5   2900          3           2    4              130
# 6   5600          2           1   16             none
# 7  nnone          4           3   15              140
# 8   1300          3        none   16               95
# 9   2400          3           2   13              115

# %%
# replace the values using replace() method
d4=df.replace(3,6)
d4
# Out:
#     Area no of boys no of girls  Age Electricity_bill
# 0   1000          6           2   15              100
# 1   1900          6           2   10              110
# 2   2300       none           6   18             none
# 3   1700          2           2   13              120
# 4   none          2           1    6               90
# 5   2900          6           2    4              130
# 6   5600          2           1   16             none
# 7  nnone          4           6   15              140
# 8   1300          6        none   16               95
# 9   2400          6           2   13              115

# %%
d5 = pd.Categorical([1,2,4,1,2,5,1,2,3,])
d5
# Out:
# [1, 2, 4, 1, 2, 5, 1, 2, 3]
# Categories (5, int64): [1, 2, 3, 4, 5]

# %%
d6 = pd.Categorical(['a','b','e', 'm', 'f', 'i', 'f', 'e', 'h', 'm' ])
d6
# Out:
# ['a', 'b', 'e', 'm', 'f', 'i', 'f', 'e', 'h', 'm']
# Categories (7, object): ['a', 'b', 'e', 'f', 'h', 'i', 'm']

# %%
dd=pd.read_excel("Marks.xlsx")
df=pd.DataFrame(dd)
df
# Out:
#    s.no    name qualifier
# 0     1     Sai      fail
# 1     2    Raju      pass
# 2     3  Ramesh      fail
# 3     4  Suresh      pass
# 4     5     Leo      pass

# %%
df.head()
# Out:
#    s.no    name qualifier
# 0     1     Sai      fail
# 1     2    Raju      pass
# 2     3  Ramesh      fail
# 3     4  Suresh      pass
# 4     5     Leo      pass

# %%
df["qualifier"].value_counts()
# Out:
# pass    3
# fail    2
# Name: qualifier, dtype: int64

# %%
encode={"qualifier":{"pass":1,"fail":0}}
encoded_df=df.replace(encode)
encoded_df
# Out:
#    s.no    name  qualifier
# 0     1     Sai          0
# 1     2    Raju          1
# 2     3  Ramesh          0
# 3     4  Suresh          1
# 4     5     Leo          1

# %%
output=encoded_df.to_excel("data.xlsx")
output

# %%
pd.read_excel("data.xlsx")
# Out:
#    Unnamed: 0  s.no    name  qualifier
# 0           0     1     Sai          0
# 1           1     2    Raju          1
# 2           2     3  Ramesh          0
# 3           3     4  Suresh          1
# 4           4     5     Leo          1

# %%
df.head()
# Out:
#    s.no    name qualifier
# 0     1     Sai      fail
# 1     2    Raju      pass
# 2     3  Ramesh      fail
# 3     4  Suresh      pass
# 4     5     Leo      pass

# %%
data=pd.read_excel("Marks.xlsx")
data.head(7)
# Out:
#    s.no    name qualifier
# 0     1     Sai      fail
# 1     2    Raju      pass
# 2     3  Ramesh      fail
# 3     4  Suresh      pass
# 4     5     Leo      pass

# %%
type(data["qualifier"])
# Out:
# pandas.core.series.Series

# %%
data.dtypes
# Out:
# s.no          int64
# name         object
# qualifier    object
# dtype: object

# %%
data["qualifier"]=data["qualifier"].astype('category')
data.dtypes
# Out:
# s.no            int64
# name           object
# qualifier    category
# dtype: object

# %%
data["qualifier_new"]=data["qualifier"].cat.codes
data
# Out:
#    s.no    name qualifier  qualifier_new
# 0     1     Sai      fail              0
# 1     2    Raju      pass              1
# 2     3  Ramesh      fail              0
# 3     4  Suresh      pass              1
# 4     5     Leo      pass              1

# %%
""" 
create a dataset of house 
s.no no.rooms doors windows
1 dinning two four
"""
# Out:
# ' \ncreate a dataset of house \ns.no no.rooms doors windows\n1 dinning two four\n'

# %%
pd.get_dummies(data,columns=["qualifier"]).head()
# Out:
#    s.no    name  qualifier_new  qualifier_fail  qualifier_pass
# 0     1     Sai              0               1               0
# 1     2    Raju              1               0               1
# 2     3  Ramesh              0               1               0
# 3     4  Suresh              1               0               1
# 4     5     Leo              1               0               1

# %%
from sklearn.preprocessing import OrdinalEncoder
obj=OrdinalEncoder()
data["encode"]=obj.fit_transform(data[["qualifier"]])
data.head(7)
# Out:
#    s.no    name qualifier  qualifier_new  encode
# 0     1     Sai      fail              0     0.0
# 1     2    Raju      pass              1     1.0
# 2     3  Ramesh      fail              0     0.0
# 3     4  Suresh      pass              1     1.0
# 4     5     Leo      pass              1     1.0

# %%
data.value_counts
# Out:
# <bound method DataFrame.value_counts of    s.no    name qualifier  qualifier_new  encode
# 0     1     Sai      fail              0     0.0
# 1     2    Raju      pass              1     1.0
# 2     3  Ramesh      fail              0     0.0
# 3     4  Suresh      pass              1     1.0
# 4     5     Leo      pass              1     1.0>
